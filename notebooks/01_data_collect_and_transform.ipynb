# %% [markdown]
# # Data Collection and Transformation
#
# ...

# %%
# Autoreload so we're using most recent modules
# %load_ext autoreload
# %autoreload 2

import sys
import os
import pandas as pd
import random
import sqlite3

# Add the project root to the Python path
notebook_dir = os.path.dirname(os.path.abspath('__file__'))
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)

# Import from src
from src.data.collection import (
    initialize_games_api,
    initialize_stats_api,
    initialize_teams_api,
    initialize_ratings_api,
    initialize_metrics_api,
    initialize_recruiting_api,
    fetch_games,
    fetch_team_game_stats,
    # get_games_df,
    # get_team_game_stats_df,
    fetch_advanced_team_game_stats,
    fetch_team_talent,
    get_calendar,
    fetch_all_ratings,
    fetch_pregame_win_probabilities,
    fetch_team_recruiting,
    initialize_betting_api,
    fetch_betting_lines
)
from src.data.transformations import(
    main as transform_data
)

from pprint import pprint
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Data Collection

# %% [markdown]
# ## Inputs

# %%
start_year = 2001
end_year = 2024

# %% [markdown]
# ## Games API

# %%
# Initialize the API
games_api = initialize_games_api()

# Fetch and store games data
print("Fetching games data...")
fetch_games(start_year, end_year, games_api)

# Fetch and store team game stats data
print("Fetching team game stats data...")
fetch_team_game_stats(start_year, end_year)

# Fetch and store calendar data
print("Fetching calendar data...")
calendar_data = get_calendar(2024, games_api)
# Out:
# Fetching games data...
# Table 'games' does not exist yet.
# Successfully fetched regular season games for 2001, conference: SEC
# Successfully fetched postseason games for 2001, conference: SEC
# Successfully fetched regular season games for 2001, conference: B1G
# Successfully fetched postseason games for 2001, conference: B1G
# Successfully fetched regular season games for 2001, conference: ACC
# Successfully fetched postseason games for 2001, conference: ACC
# Successfully fetched regular season games for 2001, conference: B12
# Successfully fetched postseason games for 2001, conference: B12
# No regular season games found for 2001, conference: PAC
# No postseason games found for 2001, conference: PAC
# Created table games
# Data appended in games
# Appended data for year 2001
# Successfully fetched regular season games for 2002, conference: SEC
# Successfully fetched postseason games for 2002, conference: SEC
# Successfully fetched regular season games for 2002, conference: B1G
# Successfully fetched postseason games for 2002, conference: B1G
# Successfully fetched regular season games for 2002, conference: ACC
# Successfully fetched postseason games for 2002, conference: ACC
# Successfully fetched regular season games for 2002, conference: B12
# Successfully fetched postseason games for 2002, conference: B12
# No regular season games found for 2002, conference: PAC
# No postseason games found for 2002, conference: PAC
# Data appended in games
# Appended data for year 2002
# Successfully fetched regular season games for 2003, conference: SEC
# Successfully fetched postseason games for 2003, conference: SEC
# Successfully fetched regular season games for 2003, conference: B1G
# Successfully fetched postseason games for 2003, conference: B1G
# Successfully fetched regular season games for 2003, conference: ACC
# Successfully fetched postseason games for 2003, conference: ACC
# Successfully fetched regular season games for 2003, conference: B12
# Successfully fetched postseason games for 2003, conference: B12
# No regular season games found for 2003, conference: PAC
# No postseason games found for 2003, conference: PAC
# Data appended in games
# Appended data for year 2003
# Successfully fetched regular season games for 2004, conference: SEC
# Successfully fetched postseason games for 2004, conference: SEC
# Successfully fetched regular season games for 2004, conference: B1G
# Successfully fetched postseason games for 2004, conference: B1G
# Successfully fetched postseason games for 2022, conference: ACC
# Successfully fetched regular season games for 2022, conference: B12
# Successfully fetched postseason games for 2022, conference: B12
# Successfully fetched regular season games for 2022, conference: PAC
# Successfully fetched postseason games for 2022, conference: PAC
# Data appended in games
# Appended data for year 2022
# Successfully fetched regular season games for 2023, conference: SEC
# Successfully fetched postseason games for 2023, conference: SEC
# Successfully fetched regular season games for 2023, conference: B1G
# Successfully fetched postseason games for 2023, conference: B1G
# Successfully fetched regular season games for 2023, conference: ACC
# Successfully fetched postseason games for 2023, conference: ACC
# Successfully fetched regular season games for 2023, conference: B12
# Successfully fetched postseason games for 2023, conference: B12
# Successfully fetched regular season games for 2023, conference: PAC
# Successfully fetched postseason games for 2023, conference: PAC
# Data appended in games
# Appended data for year 2023
# Successfully fetched regular season games for 2024, conference: SEC
# No postseason games found for 2024, conference: SEC
# Successfully fetched regular season games for 2024, conference: B1G
# No postseason games found for 2024, conference: B1G
# Successfully fetched regular season games for 2024, conference: ACC
# No postseason games found for 2024, conference: ACC
# Successfully fetched regular season games for 2024, conference: B12
# No postseason games found for 2024, conference: B12
# Successfully fetched regular season games for 2024, conference: PAC
# No postseason games found for 2024, conference: PAC
# Data appended in games
# Appended data for year 2024
# Finished fetching games data
# Fetching team game stats data...
# Table 'team_game_stats' does not exist yet.
# Successfully fetched team game stats for 2001, conference: SEC
# Successfully fetched team game stats for 2001, conference: B1G
# Successfully fetched team game stats for 2001, conference: ACC
# Successfully fetched team game stats for 2001, conference: B12
# Successfully fetched team game stats for 2001, conference: PAC
# Successfully fetched team game stats for 2002, conference: SEC
# Successfully fetched team game stats for 2002, conference: B1G
# Successfully fetched team game stats for 2002, conference: ACC
# Successfully fetched team game stats for 2002, conference: B12
# Successfully fetched team game stats for 2002, conference: PAC
# Successfully fetched team game stats for 2003, conference: SEC
# Successfully fetched team game stats for 2003, conference: B1G
# Successfully fetched team game stats for 2003, conference: ACC
# Successfully fetched team game stats for 2003, conference: B12
# Successfully fetched team game stats for 2003, conference: PAC
# Successfully fetched team game stats for 2004, conference: SEC
# Successfully fetched team game stats for 2004, conference: B1G
# Successfully fetched team game stats for 2004, conference: ACC
# Successfully fetched team game stats for 2004, conference: B12
# Successfully fetched team game stats for 2004, conference: PAC
# Created table team_game_stats
# Data appended in team_game_stats
# Appended team game stats data for year 2004
# Successfully fetched team game stats for 2005, conference: SEC
# Successfully fetched team game stats for 2005, conference: B1G
# Successfully fetched team game stats for 2005, conference: ACC
# Successfully fetched team game stats for 2005, conference: B12
# Successfully fetched team game stats for 2005, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2005
# Successfully fetched team game stats for 2006, conference: SEC
# Successfully fetched team game stats for 2006, conference: B1G
# Successfully fetched team game stats for 2006, conference: ACC
# Successfully fetched team game stats for 2006, conference: B12
# Successfully fetched team game stats for 2006, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2006
# Successfully fetched team game stats for 2007, conference: SEC
# Successfully fetched team game stats for 2007, conference: B1G
# Successfully fetched team game stats for 2007, conference: ACC
# Successfully fetched team game stats for 2007, conference: B12
# Successfully fetched team game stats for 2007, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2007
# Successfully fetched team game stats for 2008, conference: SEC
# Successfully fetched team game stats for 2008, conference: B1G
# Successfully fetched team game stats for 2008, conference: ACC
# Successfully fetched team game stats for 2008, conference: B12
# Successfully fetched team game stats for 2008, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2008
# Successfully fetched team game stats for 2009, conference: SEC
# Successfully fetched team game stats for 2009, conference: B1G
# Successfully fetched team game stats for 2009, conference: ACC
# Successfully fetched team game stats for 2009, conference: B12
# Successfully fetched team game stats for 2009, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2009
# Successfully fetched team game stats for 2010, conference: SEC
# Successfully fetched team game stats for 2010, conference: B1G
# Successfully fetched team game stats for 2010, conference: ACC
# Successfully fetched team game stats for 2010, conference: B12
# Successfully fetched team game stats for 2010, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2010
# Successfully fetched team game stats for 2011, conference: SEC
# Successfully fetched team game stats for 2011, conference: B1G
# Successfully fetched team game stats for 2011, conference: ACC
# Successfully fetched team game stats for 2011, conference: B12
# Successfully fetched team game stats for 2011, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2011
# Successfully fetched team game stats for 2012, conference: SEC
# Successfully fetched team game stats for 2012, conference: B1G
# Successfully fetched team game stats for 2012, conference: ACC
# Successfully fetched team game stats for 2012, conference: B12
# Successfully fetched team game stats for 2012, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2012
# Successfully fetched team game stats for 2013, conference: SEC
# Successfully fetched team game stats for 2013, conference: B1G
# Successfully fetched team game stats for 2013, conference: ACC
# Successfully fetched team game stats for 2013, conference: B12
# Successfully fetched team game stats for 2013, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2013
# Successfully fetched team game stats for 2014, conference: SEC
# Successfully fetched team game stats for 2014, conference: B1G
# Successfully fetched team game stats for 2014, conference: ACC
# Successfully fetched team game stats for 2014, conference: B12
# Successfully fetched team game stats for 2014, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2014
# Successfully fetched team game stats for 2015, conference: SEC
# Successfully fetched team game stats for 2015, conference: B1G
# Successfully fetched team game stats for 2015, conference: ACC
# Successfully fetched team game stats for 2015, conference: B12
# Successfully fetched team game stats for 2015, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2015
# Successfully fetched team game stats for 2016, conference: SEC
# Successfully fetched team game stats for 2016, conference: B1G
# Successfully fetched team game stats for 2016, conference: ACC
# Successfully fetched team game stats for 2016, conference: B12
# Successfully fetched team game stats for 2016, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2016
# Successfully fetched team game stats for 2017, conference: SEC
# Successfully fetched team game stats for 2017, conference: B1G
# Successfully fetched team game stats for 2017, conference: ACC
# Successfully fetched team game stats for 2017, conference: B12
# Successfully fetched team game stats for 2017, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2017
# Successfully fetched team game stats for 2018, conference: SEC
# Successfully fetched team game stats for 2018, conference: B1G
# Successfully fetched team game stats for 2018, conference: ACC
# Successfully fetched team game stats for 2018, conference: B12
# Successfully fetched team game stats for 2018, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2018
# Successfully fetched team game stats for 2019, conference: SEC
# Successfully fetched team game stats for 2019, conference: B1G
# Successfully fetched team game stats for 2019, conference: ACC
# Successfully fetched team game stats for 2019, conference: B12
# Successfully fetched team game stats for 2019, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2019
# Successfully fetched team game stats for 2020, conference: SEC
# Successfully fetched team game stats for 2020, conference: B1G
# Successfully fetched team game stats for 2020, conference: ACC
# Successfully fetched team game stats for 2020, conference: B12
# Successfully fetched team game stats for 2020, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2020
# Successfully fetched team game stats for 2021, conference: SEC
# Successfully fetched team game stats for 2021, conference: B1G
# Successfully fetched team game stats for 2021, conference: ACC
# Successfully fetched team game stats for 2021, conference: B12
# Successfully fetched team game stats for 2021, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2021
# Successfully fetched team game stats for 2022, conference: SEC
# Successfully fetched team game stats for 2022, conference: B1G
# Successfully fetched team game stats for 2022, conference: ACC
# Successfully fetched team game stats for 2022, conference: B12
# Successfully fetched team game stats for 2022, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2022
# Successfully fetched team game stats for 2023, conference: SEC
# Successfully fetched team game stats for 2023, conference: B1G
# Successfully fetched team game stats for 2023, conference: ACC
# Successfully fetched team game stats for 2023, conference: B12
# Successfully fetched team game stats for 2023, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2023
# Successfully fetched team game stats for 2024, conference: SEC
# Successfully fetched team game stats for 2024, conference: B1G
# Successfully fetched team game stats for 2024, conference: ACC
# Successfully fetched team game stats for 2024, conference: B12
# Successfully fetched team game stats for 2024, conference: PAC
# Data appended in team_game_stats
# Appended team game stats data for year 2024
# Finished fetching team game stats data
# Fetching calendar data...
# Calendar table does not exist yet.
# Created table calendar
# Calendar data for year 2024 stored/updated
# Successfully fetched and stored calendar data for 2024

# %% [markdown]
# ## Stats API

# %%
## Advanced Team Stats
stats_api = initialize_stats_api()
print("Fetching advanced team game stats...")
fetch_advanced_team_game_stats(start_year, end_year, stats_api)
# Out:
# Fetching advanced team game stats...
# Table 'advanced_team_game_stats' does not exist yet.
# Successfully fetched advanced team game stats for 2001 regular season
# Successfully fetched advanced team game stats for 2001 postseason season
# Created table advanced_team_game_stats
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2001
# Successfully fetched advanced team game stats for 2002 regular season
# Successfully fetched advanced team game stats for 2002 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2002
# Successfully fetched advanced team game stats for 2003 regular season
# Successfully fetched advanced team game stats for 2003 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2003
# Successfully fetched advanced team game stats for 2004 regular season
# Successfully fetched advanced team game stats for 2004 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2004
# Successfully fetched advanced team game stats for 2005 regular season
# Successfully fetched advanced team game stats for 2005 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2005
# Successfully fetched advanced team game stats for 2006 regular season
# Successfully fetched advanced team game stats for 2006 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2006
# Successfully fetched advanced team game stats for 2007 regular season
# Successfully fetched advanced team game stats for 2007 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2007
# Successfully fetched advanced team game stats for 2008 regular season
# Successfully fetched advanced team game stats for 2008 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2008
# Successfully fetched advanced team game stats for 2009 regular season
# Successfully fetched advanced team game stats for 2009 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2009
# Successfully fetched advanced team game stats for 2010 regular season
# Successfully fetched advanced team game stats for 2010 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2010
# Successfully fetched advanced team game stats for 2011 regular season
# Successfully fetched advanced team game stats for 2011 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2011
# Successfully fetched advanced team game stats for 2012 regular season
# Successfully fetched advanced team game stats for 2012 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2012
# Successfully fetched advanced team game stats for 2013 regular season
# Successfully fetched advanced team game stats for 2013 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2013
# Successfully fetched advanced team game stats for 2014 regular season
# Successfully fetched advanced team game stats for 2014 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2014
# Successfully fetched advanced team game stats for 2015 regular season
# Successfully fetched advanced team game stats for 2015 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2015
# Successfully fetched advanced team game stats for 2016 regular season
# Successfully fetched advanced team game stats for 2016 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2016
# Successfully fetched advanced team game stats for 2017 regular season
# Successfully fetched advanced team game stats for 2017 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2017
# Successfully fetched advanced team game stats for 2018 regular season
# Successfully fetched advanced team game stats for 2018 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2018
# Successfully fetched advanced team game stats for 2019 regular season
# Successfully fetched advanced team game stats for 2019 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2019
# Successfully fetched advanced team game stats for 2020 regular season
# Successfully fetched advanced team game stats for 2020 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2020
# Successfully fetched advanced team game stats for 2021 regular season
# Successfully fetched advanced team game stats for 2021 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2021
# Successfully fetched advanced team game stats for 2022 regular season
# Successfully fetched advanced team game stats for 2022 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2022
# Successfully fetched advanced team game stats for 2023 regular season
# Successfully fetched advanced team game stats for 2023 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2023
# Successfully fetched advanced team game stats for 2024 regular season
# Successfully fetched advanced team game stats for 2024 postseason season
# Data appended in advanced_team_game_stats
# Appended advanced team game stats data for year 2024
# Finished fetching advanced team game stats data

# %% [markdown]
# ## Ratings API

# %%
ratings_api = initialize_ratings_api()
print("Fetching all ratings data...")
fetch_all_ratings(start_year, end_year, ratings_api)
# Out:
# Fetching all ratings data...
# Successfully fetched ELO ratings for 2001
# Successfully fetched ELO ratings for 2002
# Successfully fetched ELO ratings for 2003
# Successfully fetched ELO ratings for 2004
# Successfully fetched ELO ratings for 2005
# Successfully fetched ELO ratings for 2006
# Successfully fetched ELO ratings for 2007
# Successfully fetched ELO ratings for 2008
# Successfully fetched ELO ratings for 2009
# Successfully fetched ELO ratings for 2010
# Successfully fetched ELO ratings for 2011
# Successfully fetched ELO ratings for 2012
# Successfully fetched ELO ratings for 2013
# Successfully fetched ELO ratings for 2014
# Successfully fetched ELO ratings for 2015
# Successfully fetched ELO ratings for 2016
# Successfully fetched ELO ratings for 2017
# Successfully fetched ELO ratings for 2018
# Successfully fetched ELO ratings for 2019
# Successfully fetched ELO ratings for 2020
# Successfully fetched ELO ratings for 2021
# Successfully fetched ELO ratings for 2022
# Successfully fetched ELO ratings for 2023
# Successfully fetched ELO ratings for 2024
# Replaced table elo_ratings
# Data replaced in elo_ratings
# Successfully stored all ELO ratings data
# Successfully fetched FPI ratings for 2001
# Successfully fetched FPI ratings for 2002
# Successfully fetched FPI ratings for 2003
# Successfully fetched FPI ratings for 2004
# Successfully fetched FPI ratings for 2005
# Successfully fetched FPI ratings for 2006
# Successfully fetched FPI ratings for 2007
# Successfully fetched FPI ratings for 2008
# Successfully fetched FPI ratings for 2009
# Successfully fetched FPI ratings for 2010
# Successfully fetched FPI ratings for 2011
# Successfully fetched FPI ratings for 2012
# Successfully fetched FPI ratings for 2013
# Successfully fetched FPI ratings for 2014
# Successfully fetched FPI ratings for 2015
# Successfully fetched FPI ratings for 2016
# Successfully fetched FPI ratings for 2017
# Successfully fetched FPI ratings for 2018
# Successfully fetched FPI ratings for 2019
# Successfully fetched FPI ratings for 2020
# Successfully fetched FPI ratings for 2021
# Successfully fetched FPI ratings for 2022
# Successfully fetched FPI ratings for 2023
# Successfully fetched FPI ratings for 2024
# Replaced table fpi_ratings
# Data replaced in fpi_ratings
# Successfully stored all FPI ratings data
# Successfully fetched SP ratings for 2001
# Successfully fetched SP ratings for 2002
# Successfully fetched SP ratings for 2003
# Successfully fetched SP ratings for 2004
# Successfully fetched SP ratings for 2005
# Successfully fetched SP ratings for 2006
# Successfully fetched SP ratings for 2007
# Successfully fetched SP ratings for 2008
# Successfully fetched SP ratings for 2009
# Successfully fetched SP ratings for 2010
# Successfully fetched SP ratings for 2011
# Successfully fetched SP ratings for 2012
# Successfully fetched SP ratings for 2013
# Successfully fetched SP ratings for 2014
# Successfully fetched SP ratings for 2015
# Successfully fetched SP ratings for 2016
# Successfully fetched SP ratings for 2017
# Successfully fetched SP ratings for 2018
# Successfully fetched SP ratings for 2019
# Successfully fetched SP ratings for 2020
# Successfully fetched SP ratings for 2021
# Successfully fetched SP ratings for 2022
# Successfully fetched SP ratings for 2023
# Successfully fetched SP ratings for 2024
# Replaced table sp_ratings
# Data replaced in sp_ratings
# Successfully stored all SP ratings data
# Successfully fetched SRS ratings for 2001
# Successfully fetched SRS ratings for 2002
# Successfully fetched SRS ratings for 2003
# Successfully fetched SRS ratings for 2004
# Successfully fetched SRS ratings for 2005
# Successfully fetched SRS ratings for 2006
# Successfully fetched SRS ratings for 2007
# Successfully fetched SRS ratings for 2008
# Successfully fetched SRS ratings for 2009
# Successfully fetched SRS ratings for 2010
# Successfully fetched SRS ratings for 2011
# Successfully fetched SRS ratings for 2012
# Successfully fetched SRS ratings for 2013
# Successfully fetched SRS ratings for 2014
# Successfully fetched SRS ratings for 2015
# Successfully fetched SRS ratings for 2016
# Successfully fetched SRS ratings for 2017
# Successfully fetched SRS ratings for 2018
# Successfully fetched SRS ratings for 2019
# Successfully fetched SRS ratings for 2020
# Successfully fetched SRS ratings for 2021
# Successfully fetched SRS ratings for 2022
# Successfully fetched SRS ratings for 2023
# Successfully fetched SRS ratings for 2024
# Replaced table srs_ratings
# Data replaced in srs_ratings
# Successfully stored all SRS ratings data
# Finished fetching all ratings data

# %% [markdown]
# ## Teams API

# %%
## Team Talent Composite
teams_api = initialize_teams_api()
print("Fetching team talent data...")
fetch_team_talent(start_year, end_year, teams_api)
# Out:
# Fetching team talent data...
# Table 'team_talent' does not exist yet.
# Created table team_talent
# Data appended in team_talent
# Appended team talent data for year 2015
# Successfully fetched team talent data for 2015
# Data appended in team_talent
# Appended team talent data for year 2016
# Successfully fetched team talent data for 2016
# Data appended in team_talent
# Appended team talent data for year 2017
# Successfully fetched team talent data for 2017
# Data appended in team_talent
# Appended team talent data for year 2018
# Successfully fetched team talent data for 2018
# Data appended in team_talent
# Appended team talent data for year 2019
# Successfully fetched team talent data for 2019
# Data appended in team_talent
# Appended team talent data for year 2020
# Successfully fetched team talent data for 2020
# Data appended in team_talent
# Appended team talent data for year 2021
# Successfully fetched team talent data for 2021
# Data appended in team_talent
# Appended team talent data for year 2022
# Successfully fetched team talent data for 2022
# Data appended in team_talent
# Appended team talent data for year 2023
# Successfully fetched team talent data for 2023
# Data appended in team_talent
# Appended team talent data for year 2024
# Successfully fetched team talent data for 2024
# Finished fetching team talent data

# %% [markdown]
# ## Metrics API

# %%
# Pre-game Win Probabilities
metrics_api = initialize_metrics_api()
print("Fetching pre-game win probabilities...")
fetch_pregame_win_probabilities(start_year, end_year, metrics_api)
# Appended pregame win probabilities data for year 2022
# Successfully fetched pregame win probabilities for 2023 regular season
# Successfully fetched pregame win probabilities for 2023 postseason season
# Data appended in pregame_win_probabilities
# Appended pregame win probabilities data for year 2023
# Successfully fetched pregame win probabilities for 2024 regular season
# Successfully fetched pregame win probabilities for 2024 postseason season
# Data appended in pregame_win_probabilities
# Appended pregame win probabilities data for year 2024
# Finished fetching pregame win probabilities data

# %% [markdown]
# ## Recruiting API

# %%
recruiting_api = initialize_recruiting_api()
print("Fetching recruiting data...")
fetch_team_recruiting(start_year, end_year, recruiting_api)
# Out:
# Fetching recruiting data...
# Table 'team_recruiting' does not exist yet.
# Created table team_recruiting
# Data appended in team_recruiting
# Appended team recruiting data for year 2001
# Successfully fetched team recruiting data for 2001
# Data appended in team_recruiting
# Appended team recruiting data for year 2002
# Successfully fetched team recruiting data for 2002
# Data appended in team_recruiting
# Appended team recruiting data for year 2003
# Successfully fetched team recruiting data for 2003
# Data appended in team_recruiting
# Appended team recruiting data for year 2004
# Successfully fetched team recruiting data for 2004
# Data appended in team_recruiting
# Appended team recruiting data for year 2005
# Successfully fetched team recruiting data for 2005
# Data appended in team_recruiting
# Appended team recruiting data for year 2006
# Successfully fetched team recruiting data for 2006
# Data appended in team_recruiting
# Appended team recruiting data for year 2007
# Successfully fetched team recruiting data for 2007
# Data appended in team_recruiting
# Appended team recruiting data for year 2008
# Successfully fetched team recruiting data for 2008
# Data appended in team_recruiting
# Appended team recruiting data for year 2009
# Successfully fetched team recruiting data for 2009
# Data appended in team_recruiting
# Appended team recruiting data for year 2010
# Successfully fetched team recruiting data for 2010
# Data appended in team_recruiting
# Appended team recruiting data for year 2011
# Successfully fetched team recruiting data for 2011
# Data appended in team_recruiting
# Appended team recruiting data for year 2012
# Successfully fetched team recruiting data for 2012
# Data appended in team_recruiting
# Appended team recruiting data for year 2013
# Successfully fetched team recruiting data for 2013
# Data appended in team_recruiting
# Appended team recruiting data for year 2014
# Successfully fetched team recruiting data for 2014
# Data appended in team_recruiting
# Appended team recruiting data for year 2015
# Successfully fetched team recruiting data for 2015
# Data appended in team_recruiting
# Appended team recruiting data for year 2016
# Successfully fetched team recruiting data for 2016
# Data appended in team_recruiting
# Appended team recruiting data for year 2017
# Successfully fetched team recruiting data for 2017
# Data appended in team_recruiting
# Appended team recruiting data for year 2018
# Successfully fetched team recruiting data for 2018
# Data appended in team_recruiting
# Appended team recruiting data for year 2019
# Successfully fetched team recruiting data for 2019
# Data appended in team_recruiting
# Appended team recruiting data for year 2020
# Successfully fetched team recruiting data for 2020
# Data appended in team_recruiting
# Appended team recruiting data for year 2021
# Successfully fetched team recruiting data for 2021
# Data appended in team_recruiting
# Appended team recruiting data for year 2022
# Successfully fetched team recruiting data for 2022
# Data appended in team_recruiting
# Appended team recruiting data for year 2023
# Successfully fetched team recruiting data for 2023
# Data appended in team_recruiting
# Appended team recruiting data for year 2024
# Successfully fetched team recruiting data for 2024
# Finished fetching team recruiting data

# %% [markdown]
# ## Betting API

# %%
betting_api = initialize_betting_api()
print("Fetching betting lines...")
fetch_betting_lines(start_year, end_year, betting_api)
# Out:
# Fetching betting lines...
# Table 'betting_lines' does not exist yet.
# Successfully fetched betting lines for 2013 regular season
# Successfully fetched betting lines for 2013 postseason season
# Created table betting_lines
# Data appended in betting_lines
# Appended betting lines data for year 2013
# Successfully fetched betting lines for 2014 regular season
# Successfully fetched betting lines for 2014 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2014
# Successfully fetched betting lines for 2015 regular season
# Successfully fetched betting lines for 2015 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2015
# Successfully fetched betting lines for 2016 regular season
# Successfully fetched betting lines for 2016 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2016
# Successfully fetched betting lines for 2017 regular season
# Successfully fetched betting lines for 2017 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2017
# Successfully fetched betting lines for 2018 regular season
# Successfully fetched betting lines for 2018 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2018
# Successfully fetched betting lines for 2019 regular season
# Successfully fetched betting lines for 2019 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2019
# Successfully fetched betting lines for 2020 regular season
# Successfully fetched betting lines for 2020 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2020
# Successfully fetched betting lines for 2021 regular season
# Successfully fetched betting lines for 2021 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2021
# Successfully fetched betting lines for 2022 regular season
# Successfully fetched betting lines for 2022 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2022
# Successfully fetched betting lines for 2023 regular season
# Successfully fetched betting lines for 2023 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2023
# Successfully fetched betting lines for 2024 regular season
# Successfully fetched betting lines for 2024 postseason season
# Data appended in betting_lines
# Appended betting lines data for year 2024
# Finished fetching betting lines data

# %% [markdown]
# # Data Transformation

# %%
transform_data()
# Out:
# Transforming table: games
# Transforming table: team_game_stats
# Transforming table: calendar
# Transforming table: advanced_team_game_stats
# Transforming table: team_talent
# Transforming table: pregame_win_probabilities
# Transforming table: team_recruiting
# Transforming table: betting_lines
# Transforming table: elo_ratings
# Transforming table: fpi_ratings
# Transforming table: sp_ratings
# Transforming table: srs_ratings
# Transformation complete.

# %%
new_db_path = '../data/02_interim/college_football.db'
conn = sqlite3.connect(new_db_path)

# Get table names
cursor = conn.cursor()
cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
table_names = [table[0] for table in cursor.fetchall()]

print("Tables in the new database:")
for table in table_names:
    print(table)

# Example: Load a table and display its structure
example_table = table_names[0]
df = pd.read_sql(f"SELECT * FROM {example_table} LIMIT 5", conn)
print(f"\nStructure of {example_table}:")
print(df.info())

conn.close()
# Out:
# Tables in the new database:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[13], line 14
#      11     print(table)
#      13 # Example: Load a table and display its structure
# ---> 14 example_table = table_names[0]
#      15 df = pd.read_sql(f"SELECT * FROM {example_table} LIMIT 5", conn)
#      16 print(f"\nStructure of {example_table}:")
#
# IndexError: list index out of range
