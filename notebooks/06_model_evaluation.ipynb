# %% [markdown]
# # Model Evaluation
#
# -   Evaluate models on test set
# -   Review performance metrics (accuracy, precision, recall, F1-score, etc.)
# -   Create confusion matrices and ROC curves
# -   Analyze feature importance
